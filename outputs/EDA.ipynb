# %%
#cell 0-dataset download
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kukulauren/cms-desynpuf-2010-outpatient-claims")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'cms-desynpuf-2010-outpatient-claims' dataset.
# Path to dataset files: /kaggle/input/cms-desynpuf-2010-outpatient-claims

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings
import os

# %%
#Cell 2: Load dataset and confirm structure
df = pd.read_csv('/kaggle/input/cms-desynpuf-2010-outpatient-claims/desynpuf_outpatient_claims_2010_filtered.csv')
df.columns = df.columns.str.strip()
print(f"Shape: {df.shape}")
print(f"Columns: {df.shape[1]}")
# Out:
# /tmp/ipython-input-1342839350.py:2: DtypeWarning: Columns (23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/kaggle/input/cms-desynpuf-2010-outpatient-claims/desynpuf_outpatient_claims_2010_filtered.csv')
# Shape: (175005, 76)
# Columns: 76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175005 entries, 0 to 175004
# Data columns (total 76 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   DESYNPUF_ID                     175005 non-null  object
#  1   CLM_ID                          175005 non-null  int64
#  2   SEGMENT                         175005 non-null  int64
#  3   CLM_FROM_DT                     175005 non-null  object
#  4   CLM_THRU_DT                     175005 non-null  object
#  5   PRVDR_NUM                       175005 non-null  object
#  6   CLM_PMT_AMT                     175005 non-null  float64
#  7   NCH_PRMRY_PYR_CLM_PD_AMT        175005 non-null  float64
#  8   AT_PHYSN_NPI                    174951 non-null  float64
#  9   OP_PHYSN_NPI                    30711 non-null   float64
#  10  OT_PHYSN_NPI                    94988 non-null   float64
#  11  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM  175005 non-null  float64
#  12  ICD9_DGNS_CD_1                  174990 non-null  object
#  13  ICD9_DGNS_CD_2                  111802 non-null  object
#  14  ICD9_DGNS_CD_3                  71879 non-null   object
#  15  ICD9_DGNS_CD_4                  44926 non-null   object
#  16  ICD9_DGNS_CD_5                  26771 non-null   object
#  17  ICD9_DGNS_CD_6                  17642 non-null   object
#  18  ICD9_DGNS_CD_7                  12112 non-null   object
#  19  ICD9_DGNS_CD_8                  8484 non-null    object
#  20  ICD9_DGNS_CD_9                  5931 non-null    object
#  21  ICD9_DGNS_CD_10                 714 non-null     object
#  22  ICD9_PRCDR_CD_1                 45 non-null      float64
#  23  ICD9_PRCDR_CD_2                 24 non-null      object
#  24  ICD9_PRCDR_CD_3                 15 non-null      object
#  25  ICD9_PRCDR_CD_4                 10 non-null      object
#  26  ICD9_PRCDR_CD_5                 6 non-null       object
#  27  ICD9_PRCDR_CD_6                 5 non-null       float64
#  28  NCH_BENE_PTB_DDCTBL_AMT         175005 non-null  float64
#  29  NCH_BENE_PTB_COINSRNC_AMT       175005 non-null  float64
#  30  ADMTNG_ICD9_DGNS_CD             11527 non-null   object
#  31  HCPCS_CD_1                      143384 non-null  object
#  32  HCPCS_CD_2                      101864 non-null  object
#  33  HCPCS_CD_3                      74632 non-null   object
#  34  HCPCS_CD_4                      61572 non-null   object
#  35  HCPCS_CD_5                      50788 non-null   object
#  36  HCPCS_CD_6                      42814 non-null   object
#  37  HCPCS_CD_7                      36223 non-null   object
#  38  HCPCS_CD_8                      31202 non-null   object
#  39  HCPCS_CD_9                      27293 non-null   object
#  40  HCPCS_CD_10                     24027 non-null   object
#  41  HCPCS_CD_11                     21311 non-null   object
#  42  HCPCS_CD_12                     19214 non-null   object
#  43  HCPCS_CD_13                     17167 non-null   object
#  44  HCPCS_CD_14                     15626 non-null   object
#  45  HCPCS_CD_15                     14252 non-null   object
#  46  HCPCS_CD_16                     13021 non-null   object
#  47  HCPCS_CD_17                     11918 non-null   object
#  48  HCPCS_CD_18                     10980 non-null   object
#  49  HCPCS_CD_19                     10165 non-null   object
#  50  HCPCS_CD_20                     9453 non-null    object
#  51  HCPCS_CD_21                     8785 non-null    object
#  52  HCPCS_CD_22                     8233 non-null    object
#  53  HCPCS_CD_23                     7733 non-null    object
#  54  HCPCS_CD_24                     7326 non-null    object
#  55  HCPCS_CD_25                     6879 non-null    object
#  56  HCPCS_CD_26                     6543 non-null    object
#  57  HCPCS_CD_27                     6257 non-null    object
#  58  HCPCS_CD_28                     5950 non-null    object
#  59  HCPCS_CD_29                     5669 non-null    object
#  60  HCPCS_CD_30                     5364 non-null    object
#  61  HCPCS_CD_31                     5094 non-null    object
#  62  HCPCS_CD_32                     4861 non-null    object
#  63  HCPCS_CD_33                     4624 non-null    object
#  64  HCPCS_CD_34                     4385 non-null    object
#  65  HCPCS_CD_35                     4161 non-null    object
#  66  HCPCS_CD_36                     4007 non-null    object
#  67  HCPCS_CD_37                     3821 non-null    object
#  68  HCPCS_CD_38                     3602 non-null    object
#  69  HCPCS_CD_39                     3454 non-null    object
#  70  HCPCS_CD_40                     3246 non-null    object
#  71  HCPCS_CD_41                     3044 non-null    object
#  72  HCPCS_CD_42                     2866 non-null    object
#  73  HCPCS_CD_43                     2703 non-null    object
#  74  HCPCS_CD_44                     2554 non-null    object
#  75  HCPCS_CD_45                     0 non-null       float64
# dtypes: float64(11), int64(2), object(63)
# memory usage: 101.5+ MB

# %%
df.describe()
# Out:
#              CLM_ID   SEGMENT    CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  \
# count  1.750050e+05  175005.0  175005.000000             175005.000000
# mean   5.425029e+14       1.0     278.593297                  8.867918
# std    2.856822e+11       0.0     560.317965                199.751233
# min    5.420123e+14       1.0    -100.000000                  0.000000
# 25%    5.422523e+14       1.0      40.000000                  0.000000
# 50%    5.425023e+14       1.0      80.000000                  0.000000
# 75%    5.427523e+14       1.0     200.000000                  0.000000
# max    5.429923e+14       1.0    3300.000000              14000.000000
#
#        AT_PHYSN_NPI  OP_PHYSN_NPI  OT_PHYSN_NPI  \
# count  1.749510e+05  3.071100e+04  9.498800e+04
# mean   4.976513e+09  4.993627e+09  4.905460e+09
# std    2.876214e+09  2.894417e+09  2.889798e+09
# min    1.024080e+05  1.053861e+06  1.024080e+05
# 25%    2.519737e+09  2.499852e+09  2.443058e+09
# 50%    4.904844e+09  4.954531e+09  4.786623e+09
# 75%    7.503305e+09  7.522857e+09  7.490283e+09
# max    9.999355e+09  9.999615e+09  9.999470e+09
#
#        NCH_BENE_BLOOD_DDCTBL_LBLTY_AM  ICD9_PRCDR_CD_1  ICD9_PRCDR_CD_6  \
# count                   175005.000000        45.000000         5.000000
# mean                         0.008571      6284.044444     26375.200000
# std                          1.772770      3226.302161     33124.684288
# min                          0.000000       309.000000      2724.000000
# 25%                          0.000000      3893.000000      3384.000000
# 50%                          0.000000      5101.000000      6826.000000
# 75%                          0.000000      9672.000000     40390.000000
# max                        500.000000      9955.000000     78552.000000
#
#        NCH_BENE_PTB_DDCTBL_AMT  NCH_BENE_PTB_COINSRNC_AMT  HCPCS_CD_45
# count            175005.000000              175005.000000          0.0
# mean                  3.034199                  81.208423          NaN
# std                  17.522852                 176.867119          NaN
# min                   0.000000                   0.000000          NaN
# 25%                   0.000000                   0.000000          NaN
# 50%                   0.000000                  20.000000          NaN
# 75%                   0.000000                  70.000000          NaN
# max                 200.000000                1100.000000          NaN
